# %%
import numpy as np
import pandas as pd
from pandas.core.common import SettingWithCopyWarning
from pathlib import Path
from glob import glob
from pathlib import Path
from time import time
import warnings

from utils import *

warnings.simplefilter(action="ignore", category=SettingWithCopyWarning)
set_pyplot_options(figsize=10)

np.random.seed(42)

# %%
LABEL = {'jog_forward': 0, 'jog_turn': 1, 'walk_forward': 2, 'walk_turn': 3, 'run_forward':4, 'stationary':5}
n_sample = 100

dir_data = Path('data/datasets_fin')


# Get all train samples, 1sec for each sample
def divide_df(df, sample_num=100, overlap=0):
    num_divs = (df.shape[0]-overlap)// (sample_num-overlap)
    df_divs = []
    for idx in range(num_divs):
        div = df[idx*(sample_num-overlap):idx*(sample_num-overlap)+sample_num]
        div.reset_index(drop=True, inplace=True)
        df_divs.append(div.copy())
    return df_divs


dfs_all = {}
for label in LABEL:
    # Read data files for each label and form 1 sec duration dataframes attached with 0.1 ms margin.
    dfs_all[label] = []
    for i, label_dir in enumerate((dir_data/label).iterdir()):
        df = pd.read_csv(label_dir)
        df_list = divide_df(df, sample_num=n_sample+10, overlap=(int(n_sample/2)+10))
        for f in df_list:
            dfs_all[label].append(f)
    
    # Remove dataframes that have discontinuities in GNSS sample points.
    # Remvoe dataframes that have inconsistent time interval (i.e. not 100ms) of GNSS samples.
    # Align time axis of GNSS points to ten'th rows
    del_list = []
    for i, df in enumerate(dfs_all[label]):
        # Time discontinuity (not 10ms)
        time_diff = df['time'].iloc[1:].to_numpy()-df['time'].iloc[:-1].to_numpy()
        a = np.where(time_diff != 1)
        if(a[0].shape[0] != 0):
            del dfs_all[label][i]
            continue
        gnss_idx = df[df['enu_x'].notna()][:].index.to_numpy()
        # GNSS point loss
        if(len(gnss_idx)<=10):
            del_list.append(i)
            continue
        a = np.where(gnss_idx%10 != 0)
        if(a[0].shape[0] != 0):
            time_diff = gnss_idx[1:]-gnss_idx[:-1]
            if(True in (time_diff != 10)): 
                del_list.append(i)
            else:
                dfs_all[label][i] = dfs_all[label][i].iloc[gnss_idx[0]:gnss_idx[0]+n_sample+1].reset_index(drop=True)
        
        else:
            dfs_all[label][i] = dfs_all[label][i].iloc[:n_sample+1].reset_index(drop=True)
    dfs_all[label] = [x for (i,x) in enumerate(dfs_all[label]) if i not in del_list]
    print("Duration of datasets(sec) ", label, len(dfs_all[label]))


# Select test samples randomly for each class
dfs_test = {}
dfs_train = {}
num_test = 100
for i, label in enumerate(LABEL):
    choice = np.random.choice(np.arange(len(dfs_all[label])), size=num_test, replace=False)
    dfs_test[label] = [x for (i, x) in enumerate(dfs_all[label]) if i in choice]
    dfs_train[label] = [x for (i, x) in enumerate(dfs_all[label]) if i not in choice]
# Out:
# Duration of datasets(sec)  jog_forward 2019
# Duration of datasets(sec)  jog_turn 987
# Duration of datasets(sec)  walk_forward 2977
# Duration of datasets(sec)  walk_turn 1036
# Duration of datasets(sec)  run_forward 1029
# Duration of datasets(sec)  stationary 496

# %%
# Get signal images from train samples
def build_signal_image(df_org, sr_imu=100):
    n_samples = sr_imu
    cols = list(df_org.columns)
    raw_signal = df_org[:n_samples][['gyrX', 'gyrY', 'gyrZ', 'eulR', 'eulP', 'eulY']].to_numpy().copy().T
    raw_signal[[0,1,2]] *= 180/np.pi
    signal_index_sequence = [1, 2, 3, 4, 5, 6, 1, 3, 
                             5, 1, 4, 6, 2, 4, 5, 2]
    signal_image = np.array([raw_signal[idx-1] for idx in signal_index_sequence], dtype=float)
    signal_image = np.reshape(signal_image, (1, 16, sr_imu))
    
    return signal_image


train_images = []
train_labels = []
train_gnss = []
for i, label in enumerate(LABEL.keys()):
    for j, df in enumerate(dfs_train[label]):
        image = build_signal_image(df)
        train_images.append(image)
        train_labels.append(LABEL[label])
        df['label'] = np.ones(len(df))*LABEL[label]
        df = df.dropna(subset=['enu_x']).loc[:,['time','enu_x','enu_y','speed','label']]
        df.reset_index(drop=True, inplace=True)
        train_gnss.append(df.to_numpy().T)
train_images = np.stack(train_images).reshape([-1,16,100])
train_labels = np.stack(train_labels).reshape([-1,1])
train_gnss = np.array(train_gnss)

test_images = []
test_labels = []
test_gnss = []
for i, label in enumerate(LABEL.keys()):
    for j, df in enumerate(dfs_test[label]):
        image = build_signal_image(df)
        test_images.append(image)
        test_labels.append(LABEL[label])
        df['label'] = np.ones(len(df))*LABEL[label]
        df = df.dropna(subset=['enu_x']).loc[:,['time','enu_x','enu_y','speed','label']]
        df.reset_index(drop=True, inplace=True)
        test_gnss.append(df.to_numpy().T)
test_images = np.stack(test_images).reshape([-1,16,100])
test_labels = np.stack(test_labels).reshape([-1,1])
test_gnss = np.array(test_gnss)

#print("Done constructing signal images", end='')
print("TRAIN / imu_signal_img:{}, labels:{}, gnss:{}".format(train_images.shape, train_labels.shape, train_gnss.shape, end=''))
print("TEST /imu_signal_img:{}, labels:{}, gnss:{}".format(test_images.shape, test_labels.shape, test_gnss.shape))
print()


np.save(dir_data / "train_gnss.npy", train_gnss)
np.save(dir_data / 'test_gnss.npy', test_gnss)
np.save(dir_data / "train_images.npy", train_images)
np.save(dir_data / 'train_labels.npy', train_labels)
np.save(dir_data / "test_images.npy", test_images)
np.save(dir_data / 'test_labels.npy', test_labels)
# Out:
# TRAIN / imu_signal_img:(7944, 16, 100), labels:(7944, 1), gnss:(7944, 5, 11)
# TEST /imu_signal_img:(600, 16, 100), labels:(600, 1), gnss:(600, 5, 11)

# %% [markdown]
# # Various IMU rate
# This cell is for generating dataset including various imu sampling rates

# %%
def downsample_imu(images, from_f, to_f):
    interval = int(from_f/to_f)
    assert interval == float(from_f)/to_f, "The sampling rate ratio must be a integer"
    return images[:,:,::interval]


def interpolate_imu(a, from_f, to_f):
    interval = int(to_f/from_f)
    assert interval == float(to_f)/from_f, "The sampling rate ratio must be a integer"
    arr = np.zeros([a.shape[0], a.shape[1], a.shape[2]*interval], dtype=a.dtype)
    arr[:,:,::interval] = a
    inc = np.zeros(a.shape)
    inc[:,:,:-1] = (a[:,:,1:] - a[:,:,:-1])/interval
    inc[:,:,-1] = inc[:,:,-2]
    for i in range(1,interval):
        arr[:,:,i::interval] = arr[:,:,::interval] + inc*i
    
    return arr

SR_IMU = [100,50,20,10]
train_images_ds = []
test_images_ds = []
train_labels_ds = []
test_labels_ds = []
train_gnss_ds = []
test_gnss_ds = []
for sr_imu in SR_IMU:
    d = downsample_imu(train_images, n_sample, sr_imu)
    d = interpolate_imu(d, sr_imu, n_sample)
    train_images_ds.append(d)
    train_labels_ds.append(train_labels)
    train_gnss_ds.append(train_gnss)
    
    d = downsample_imu(test_images, n_sample, sr_imu)
    d = interpolate_imu(d, sr_imu, n_sample)
    test_images_ds.append(d)
    test_labels_ds.append(test_labels)
    test_gnss_ds.append(test_gnss)

train_images = np.concatenate(train_images_ds)
train_labels = np.concatenate(train_labels_ds)
test_images = np.concatenate(test_images_ds)
test_labels = np.concatenate(test_labels_ds)
train_gnss = np.concatenate(train_gnss_ds)
test_gnss = np.concatenate(test_gnss_ds)

print("TRAIN / imu_signal_img:{}, labels:{}, gnss:{}".format(train_images.shape, train_labels.shape, train_gnss.shape, end=''))
print("TEST /imu_signal_img:{}, labels:{}, gnss:{}".format(test_images.shape, test_labels.shape, test_gnss.shape))

np.save(dir_data / "train_images_imu_mix.npy", train_images)
np.save(dir_data / 'train_labels_imu_mix.npy', train_labels)
np.save(dir_data / "test_images_imu_mix.npy", test_images)
np.save(dir_data / 'test_labels_imu_mix.npy', test_labels)
np.save(dir_data / "test_gnss_imu_mix.npy", test_gnss)
np.save(dir_data / 'train_gnss_imu_mix.npy', train_gnss)
print("Done saving npy files")
# Out:
# TRAIN / imu_signal_img:(31776, 16, 100), labels:(31776, 1), gnss:(31776, 5, 11)
# TEST /imu_signal_img:(2400, 16, 100), labels:(2400, 1), gnss:(2400, 5, 11)
# Done saving npy files

# %% [markdown]
# # Model training

# %%
# !python train_harcnn.py --n_epochs 200 --lr 1e-4 --n_classes 6 --n_samples 100 --output_dir "./models/" --input_dir "./data/datasets_fin"
# Out:
# 2020-09-10 12:36:05.176464: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.2
# 2020-09-10 12:36:06.055205: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libnvinfer.so.7
# 2020-09-10 12:36:06.056226: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libnvinfer_plugin.so.7
# ==> Training..
# Epoch: 1
# Train Loss: 2.449 | Acc: 56.514%
# Test Loss: 0.166 | Acc: 55.125%
#
# Epoch: 2
# Train Loss: 1.530 | Acc: 79.167%
# Test Loss: 0.128 | Acc: 69.125%
#
# Epoch: 3
# Train Loss: 1.091 | Acc: 84.998%
# Test Loss: 0.105 | Acc: 72.333%
#
# Epoch: 4
# Train Loss: 0.821 | Acc: 87.531%
# Test Loss: 0.083 | Acc: 75.125%
#
# Epoch: 5
# Train Loss: 0.662 | Acc: 88.466%
# Test Loss: 0.068 | Acc: 75.208%
#
# Epoch: 6
# Train Loss: 0.551 | Acc: 91.380%
# Test Loss: 0.049 | Acc: 92.375%
#
# Epoch: 7
# Train Loss: 0.472 | Acc: 94.276%
# Test Loss: 0.046 | Acc: 91.958%
#
# Epoch: 8
# Train Loss: 0.418 | Acc: 94.732%
# Test Loss: 0.038 | Acc: 93.958%
#
# Epoch: 9
# Train Loss: 0.384 | Acc: 95.006%
# Test Loss: 0.033 | Acc: 94.583%
#
# Epoch: 10
# Train Loss: 0.356 | Acc: 95.220%
# Test Loss: 0.029 | Acc: 95.125%
#
# Epoch: 11
# Train Loss: 0.333 | Acc: 95.613%
# Test Loss: 0.027 | Acc: 95.750%
#
# Epoch: 12
# Train Loss: 0.312 | Acc: 95.761%
# Test Loss: 0.026 | Acc: 95.542%
#
# Epoch: 13
# Train Loss: 0.302 | Acc: 95.755%
# Test Loss: 0.025 | Acc: 95.833%
#
# Epoch: 14
# Train Loss: 0.286 | Acc: 95.934%
# Test Loss: 0.024 | Acc: 95.583%
#
# Epoch: 15
# Train Loss: 0.273 | Acc: 96.091%
# Test Loss: 0.024 | Acc: 95.375%
#
# Epoch: 16
# Train Loss: 0.269 | Acc: 96.186%
# Test Loss: 0.024 | Acc: 95.250%
#
# Epoch: 17
# Train Loss: 0.264 | Acc: 96.063%
# Test Loss: 0.022 | Acc: 95.625%
#
# Epoch: 18
# Train Loss: 0.252 | Acc: 96.324%
# Test Loss: 0.020 | Acc: 96.500%
#
# Epoch: 19
# Train Loss: 0.242 | Acc: 96.346%
# Test Loss: 0.026 | Acc: 94.792%
#
# Epoch: 20
# Train Loss: 0.236 | Acc: 96.469%
# Test Loss: 0.021 | Acc: 95.875%
#
# Epoch: 21
# Train Loss: 0.236 | Acc: 96.419%
# Test Loss: 0.026 | Acc: 94.500%
#
# Epoch: 22
# Train Loss: 0.229 | Acc: 96.526%
# Test Loss: 0.022 | Acc: 95.375%
#
# Epoch: 23
# Train Loss: 0.222 | Acc: 96.604%
# Test Loss: 0.018 | Acc: 96.500%
#
# Epoch: 24
# Train Loss: 0.226 | Acc: 96.551%
# Test Loss: 0.020 | Acc: 95.583%
#
# Epoch: 25
# Train Loss: 0.215 | Acc: 96.645%
# Test Loss: 0.018 | Acc: 96.583%
#
# Epoch: 26
# Train Loss: 0.215 | Acc: 96.674%
# Test Loss: 0.023 | Acc: 93.917%
#
# Epoch: 27
# Train Loss: 0.213 | Acc: 96.689%
# Test Loss: 0.017 | Acc: 96.458%
#
# Epoch: 28
# Train Loss: 0.207 | Acc: 96.765%
# Test Loss: 0.017 | Acc: 96.542%
#
# Epoch: 29
# Train Loss: 0.202 | Acc: 96.806%
# Test Loss: 0.017 | Acc: 96.375%
#
# Epoch: 30
# Train Loss: 0.196 | Acc: 96.919%
# Test Loss: 0.018 | Acc: 96.167%
#
# Epoch: 31
# Train Loss: 0.193 | Acc: 96.976%
# Test Loss: 0.016 | Acc: 96.542%
#
# Epoch: 32
# Train Loss: 0.190 | Acc: 97.001%
# Test Loss: 0.016 | Acc: 96.792%
#
# Epoch: 33
# Train Loss: 0.193 | Acc: 96.966%
# Test Loss: 0.017 | Acc: 96.167%
#
# Epoch: 34
# Train Loss: 0.189 | Acc: 96.960%
# Test Loss: 0.018 | Acc: 96.042%
#
# Epoch: 35
# Train Loss: 0.186 | Acc: 97.051%
# Test Loss: 0.014 | Acc: 97.083%
#
# Epoch: 36
# Train Loss: 0.189 | Acc: 97.001%
# Test Loss: 0.015 | Acc: 96.917%
#
# Epoch: 37
# Train Loss: 0.181 | Acc: 97.045%
# Test Loss: 0.015 | Acc: 96.750%
#
# Epoch: 38
# Train Loss: 0.178 | Acc: 97.165%
# Test Loss: 0.015 | Acc: 96.833%
#
# Epoch: 39
# Train Loss: 0.177 | Acc: 97.117%
# Test Loss: 0.015 | Acc: 96.708%
#
# Epoch: 40
# Train Loss: 0.176 | Acc: 97.086%
# Test Loss: 0.015 | Acc: 96.250%
#
# Epoch: 41
# Train Loss: 0.175 | Acc: 97.149%
# Test Loss: 0.017 | Acc: 96.333%
#
# Epoch: 42
# Train Loss: 0.176 | Acc: 97.020%
# Test Loss: 0.016 | Acc: 96.250%
#
# Epoch: 43
# Train Loss: 0.168 | Acc: 97.180%
# Test Loss: 0.014 | Acc: 96.792%
#
# Epoch: 44
# Train Loss: 0.167 | Acc: 97.253%
# Test Loss: 0.017 | Acc: 96.125%
#
# Epoch: 45
# Train Loss: 0.166 | Acc: 97.221%
# Test Loss: 0.016 | Acc: 96.458%
#
# Epoch: 46
# Train Loss: 0.163 | Acc: 97.338%
# Test Loss: 0.016 | Acc: 96.000%
#
# Epoch: 47
# Train Loss: 0.161 | Acc: 97.316%
# Test Loss: 0.014 | Acc: 97.000%
#
# Epoch: 48
# Train Loss: 0.162 | Acc: 97.281%
# Test Loss: 0.014 | Acc: 96.708%
#
# Epoch: 49
# Train Loss: 0.164 | Acc: 97.303%
# Test Loss: 0.014 | Acc: 97.208%
#
# Epoch: 50
# Train Loss: 0.166 | Acc: 97.209%
# Test Loss: 0.015 | Acc: 96.542%
#
# Epoch: 51
# Train Loss: 0.157 | Acc: 97.360%
# Test Loss: 0.015 | Acc: 96.708%
#
# Epoch: 52
# Train Loss: 0.155 | Acc: 97.375%
# Test Loss: 0.014 | Acc: 97.208%
#
# Epoch: 53
# Train Loss: 0.158 | Acc: 97.290%
# Test Loss: 0.013 | Acc: 97.125%
#
# Epoch: 54
# Train Loss: 0.150 | Acc: 97.401%
# Test Loss: 0.013 | Acc: 97.333%
#
# Epoch: 55
# Train Loss: 0.155 | Acc: 97.385%
# Test Loss: 0.015 | Acc: 96.750%
#
# Epoch: 56
# Train Loss: 0.153 | Acc: 97.441%
# Test Loss: 0.012 | Acc: 97.292%
#
# Epoch: 57
# Train Loss: 0.148 | Acc: 97.457%
# Test Loss: 0.012 | Acc: 97.667%
#
# Epoch: 58
# Train Loss: 0.150 | Acc: 97.397%
# Test Loss: 0.018 | Acc: 95.458%
#
# Epoch: 59
# Train Loss: 0.150 | Acc: 97.423%
# Test Loss: 0.011 | Acc: 97.792%
#
# Epoch: 60
# Train Loss: 0.150 | Acc: 97.416%
# Test Loss: 0.013 | Acc: 97.250%
#
# Epoch: 61
# Train Loss: 0.146 | Acc: 97.476%
# Test Loss: 0.017 | Acc: 96.042%
#
# Epoch: 62
# Train Loss: 0.148 | Acc: 97.460%
# Test Loss: 0.013 | Acc: 96.833%
#
# Epoch: 63
# Train Loss: 0.143 | Acc: 97.523%
# Test Loss: 0.012 | Acc: 97.500%
#
# Epoch: 64
# Train Loss: 0.142 | Acc: 97.577%
# Test Loss: 0.013 | Acc: 97.125%
#
# Epoch: 65
# Train Loss: 0.143 | Acc: 97.533%
# Test Loss: 0.018 | Acc: 96.125%
#
# Epoch: 66
# Train Loss: 0.147 | Acc: 97.413%
# Test Loss: 0.012 | Acc: 97.250%
#
# Epoch: 67
# Train Loss: 0.139 | Acc: 97.674%
# Test Loss: 0.012 | Acc: 97.167%
#
# Epoch: 68
# Train Loss: 0.136 | Acc: 97.696%
# Test Loss: 0.012 | Acc: 97.333%
#
# Epoch: 69
# Train Loss: 0.139 | Acc: 97.567%
# Test Loss: 0.012 | Acc: 97.292%
#
# Epoch: 70
# Train Loss: 0.135 | Acc: 97.665%
# Test Loss: 0.012 | Acc: 97.458%
#
# Epoch: 71
# Train Loss: 0.137 | Acc: 97.621%
# Test Loss: 0.011 | Acc: 97.292%
#
# Epoch: 72
# Train Loss: 0.134 | Acc: 97.684%
# Test Loss: 0.011 | Acc: 97.458%
#
# Epoch: 73
# Train Loss: 0.135 | Acc: 97.652%
# Test Loss: 0.013 | Acc: 96.833%
#
# Epoch: 74
# Train Loss: 0.132 | Acc: 97.744%
# Test Loss: 0.013 | Acc: 96.917%
#
# Epoch: 75
# Train Loss: 0.133 | Acc: 97.734%
# Test Loss: 0.013 | Acc: 96.958%
#
# Epoch: 76
# Train Loss: 0.135 | Acc: 97.706%
# Test Loss: 0.013 | Acc: 97.083%
#
# Epoch: 77
# Train Loss: 0.133 | Acc: 97.700%
# Test Loss: 0.011 | Acc: 97.542%
#
# Epoch: 78
# Train Loss: 0.132 | Acc: 97.677%
# Test Loss: 0.012 | Acc: 97.333%
#
# Epoch: 79
# Train Loss: 0.128 | Acc: 97.781%
# Test Loss: 0.012 | Acc: 97.333%
#
# Epoch: 80
# Train Loss: 0.125 | Acc: 97.784%
# Test Loss: 0.013 | Acc: 97.167%
#
# Epoch: 81
# Train Loss: 0.129 | Acc: 97.769%
# Test Loss: 0.013 | Acc: 97.000%
#
# Epoch: 82
# Train Loss: 0.127 | Acc: 97.813%
# Test Loss: 0.010 | Acc: 97.750%
#
# Epoch: 83
# Train Loss: 0.129 | Acc: 97.696%
# Test Loss: 0.011 | Acc: 97.542%
#
# Epoch: 84
# Train Loss: 0.126 | Acc: 97.775%
# Test Loss: 0.011 | Acc: 97.458%
#
# Epoch: 85
# Train Loss: 0.125 | Acc: 97.740%
# Test Loss: 0.012 | Acc: 97.417%
#
# Epoch: 86
# Train Loss: 0.124 | Acc: 97.791%
# Test Loss: 0.011 | Acc: 97.500%
#
# Epoch: 87
# Train Loss: 0.122 | Acc: 97.847%
# Test Loss: 0.012 | Acc: 97.333%
#
# Epoch: 88
# Train Loss: 0.123 | Acc: 97.803%
# Test Loss: 0.010 | Acc: 97.833%
#
# Epoch: 89
# Train Loss: 0.123 | Acc: 97.781%
# Test Loss: 0.013 | Acc: 97.000%
#
# Epoch: 90
# Train Loss: 0.119 | Acc: 97.926%
# Test Loss: 0.014 | Acc: 96.833%
#
# Epoch: 91
# Train Loss: 0.121 | Acc: 97.857%
# Test Loss: 0.016 | Acc: 96.292%
#
# Epoch: 92
# Train Loss: 0.123 | Acc: 97.851%
# Test Loss: 0.010 | Acc: 97.833%
#
# Epoch: 93
# Train Loss: 0.120 | Acc: 97.844%
# Test Loss: 0.012 | Acc: 97.458%
#
# Epoch: 94
# Train Loss: 0.121 | Acc: 97.816%
# Test Loss: 0.010 | Acc: 97.792%
#
# Epoch: 95
# Train Loss: 0.120 | Acc: 97.895%
# Test Loss: 0.012 | Acc: 97.375%
#
# Epoch: 96
# Train Loss: 0.120 | Acc: 97.807%
# Test Loss: 0.011 | Acc: 97.458%
#
# Epoch: 97
# Train Loss: 0.119 | Acc: 97.907%
# Test Loss: 0.012 | Acc: 97.292%
#
# Epoch: 98
# Train Loss: 0.123 | Acc: 97.822%
# Test Loss: 0.011 | Acc: 97.458%
#
# Epoch: 99
# Train Loss: 0.116 | Acc: 97.964%
# Test Loss: 0.010 | Acc: 97.667%
#
# Epoch: 100
# Train Loss: 0.116 | Acc: 98.030%
# Test Loss: 0.011 | Acc: 97.708%
#
# Epoch: 101
# Train Loss: 0.117 | Acc: 97.873%
# Test Loss: 0.011 | Acc: 97.583%
#
# Epoch: 102
# Train Loss: 0.117 | Acc: 98.008%
# Test Loss: 0.012 | Acc: 97.417%
#
# Epoch: 103
# Train Loss: 0.113 | Acc: 98.005%
# Test Loss: 0.011 | Acc: 97.625%
#
# Epoch: 104
# Train Loss: 0.117 | Acc: 97.901%
# Test Loss: 0.016 | Acc: 96.542%
#
# Epoch: 105
# Train Loss: 0.112 | Acc: 97.998%
# Test Loss: 0.011 | Acc: 97.500%
#
# Epoch: 106
# Train Loss: 0.113 | Acc: 97.932%
# Test Loss: 0.010 | Acc: 97.583%
#
# Epoch: 107
# Train Loss: 0.115 | Acc: 97.954%
# Test Loss: 0.015 | Acc: 96.875%
#
# Epoch: 108
# Train Loss: 0.116 | Acc: 97.929%
# Test Loss: 0.013 | Acc: 97.083%
#
# Epoch: 109
# Train Loss: 0.112 | Acc: 97.989%
# Test Loss: 0.010 | Acc: 97.708%
#
# Epoch: 110
# Train Loss: 0.111 | Acc: 97.986%
# Test Loss: 0.010 | Acc: 97.708%
#
# Epoch: 111
# Train Loss: 0.109 | Acc: 98.096%
# Test Loss: 0.012 | Acc: 97.417%
#
# Epoch: 112
# Train Loss: 0.117 | Acc: 97.854%
# Test Loss: 0.011 | Acc: 97.500%
#
# Epoch: 113
# Train Loss: 0.109 | Acc: 98.096%
# Test Loss: 0.010 | Acc: 97.708%
#
# Epoch: 114
# Train Loss: 0.111 | Acc: 98.027%
# Test Loss: 0.011 | Acc: 97.625%
#
# Epoch: 115
# Train Loss: 0.107 | Acc: 98.080%
# Test Loss: 0.013 | Acc: 97.208%
#
# Epoch: 116
# Train Loss: 0.110 | Acc: 98.033%
# Test Loss: 0.011 | Acc: 97.708%
#
# Epoch: 117
# Train Loss: 0.113 | Acc: 97.914%
# Test Loss: 0.010 | Acc: 97.833%
#
# Epoch: 118
# Train Loss: 0.105 | Acc: 98.165%
# Test Loss: 0.011 | Acc: 97.708%
#
# Epoch: 119
# Train Loss: 0.109 | Acc: 98.033%
# Test Loss: 0.010 | Acc: 97.708%
#
# Epoch: 120
# Train Loss: 0.107 | Acc: 98.083%
# Test Loss: 0.011 | Acc: 97.583%
#
# Epoch: 121
# Train Loss: 0.108 | Acc: 98.030%
# Test Loss: 0.011 | Acc: 97.667%
#
# Epoch: 122
# Train Loss: 0.109 | Acc: 98.043%
# Test Loss: 0.012 | Acc: 97.125%
#
# Epoch: 123
# Train Loss: 0.107 | Acc: 98.102%
# Test Loss: 0.009 | Acc: 98.125%
#
# Epoch: 124
# Train Loss: 0.103 | Acc: 98.153%
# Test Loss: 0.011 | Acc: 97.667%
#
# Epoch: 125
# Train Loss: 0.110 | Acc: 97.986%
# Test Loss: 0.010 | Acc: 97.583%
#
# Epoch: 126
# Train Loss: 0.108 | Acc: 98.058%
# Test Loss: 0.013 | Acc: 96.750%
#
# Epoch: 127
# Train Loss: 0.107 | Acc: 98.058%
# Test Loss: 0.010 | Acc: 97.833%
#
# Epoch: 128
# Train Loss: 0.104 | Acc: 98.172%
# Test Loss: 0.011 | Acc: 97.458%
#
# Epoch: 129
# Train Loss: 0.105 | Acc: 98.156%
# Test Loss: 0.010 | Acc: 97.792%
#
# Epoch: 130
# Train Loss: 0.102 | Acc: 98.165%
# Test Loss: 0.011 | Acc: 97.542%
#
# Epoch: 131
# Train Loss: 0.102 | Acc: 98.156%
# Test Loss: 0.010 | Acc: 97.833%
#
# Epoch: 132
# Train Loss: 0.100 | Acc: 98.206%
# Test Loss: 0.010 | Acc: 97.500%
#
# Epoch: 133
# Train Loss: 0.105 | Acc: 98.118%
# Test Loss: 0.010 | Acc: 98.000%
#
# Epoch: 134
# Train Loss: 0.103 | Acc: 98.228%
# Test Loss: 0.009 | Acc: 97.917%
#
# Epoch: 135
# Train Loss: 0.103 | Acc: 98.244%
# Test Loss: 0.011 | Acc: 97.292%
#
# Epoch: 136
# Train Loss: 0.105 | Acc: 98.096%
# Test Loss: 0.011 | Acc: 97.375%
#
# Epoch: 137
# Train Loss: 0.101 | Acc: 98.231%
# Test Loss: 0.011 | Acc: 97.667%
#
# Epoch: 138
# Train Loss: 0.101 | Acc: 98.216%
# Test Loss: 0.010 | Acc: 97.833%
#
# Epoch: 139
# Train Loss: 0.101 | Acc: 98.165%
# Test Loss: 0.010 | Acc: 97.958%
#
# Epoch: 140
# Train Loss: 0.102 | Acc: 98.194%
# Test Loss: 0.011 | Acc: 97.583%
#
# Epoch: 141
# Train Loss: 0.096 | Acc: 98.216%
# Test Loss: 0.009 | Acc: 97.958%
#
# Epoch: 142
# Train Loss: 0.097 | Acc: 98.329%
# Test Loss: 0.010 | Acc: 97.917%
#
# Epoch: 143
# Train Loss: 0.096 | Acc: 98.257%
# Test Loss: 0.009 | Acc: 98.042%
#
# Epoch: 144
# Train Loss: 0.095 | Acc: 98.294%
# Test Loss: 0.010 | Acc: 97.625%
#
# Epoch: 145
# Train Loss: 0.095 | Acc: 98.279%
# Test Loss: 0.009 | Acc: 98.042%
#
# Epoch: 146
# Train Loss: 0.099 | Acc: 98.197%
# Test Loss: 0.010 | Acc: 97.708%
#
# Epoch: 147
# Train Loss: 0.097 | Acc: 98.228%
# Test Loss: 0.010 | Acc: 97.542%
#
# Epoch: 148
# Train Loss: 0.099 | Acc: 98.269%
# Test Loss: 0.010 | Acc: 97.750%
#
# Epoch: 149
# Train Loss: 0.100 | Acc: 98.184%
# Test Loss: 0.009 | Acc: 98.000%
#
# Epoch: 150
# Train Loss: 0.099 | Acc: 98.181%
# Test Loss: 0.011 | Acc: 97.417%
#
# Epoch: 151
# Train Loss: 0.100 | Acc: 98.203%
# Test Loss: 0.011 | Acc: 97.708%
#
# Epoch: 152
# Train Loss: 0.097 | Acc: 98.257%
# Test Loss: 0.010 | Acc: 97.750%
#
# Epoch: 153
# Train Loss: 0.094 | Acc: 98.379%
# Test Loss: 0.010 | Acc: 97.833%
#
# Epoch: 154
# Train Loss: 0.095 | Acc: 98.304%
# Test Loss: 0.014 | Acc: 96.500%
#
# Epoch: 155
# Train Loss: 0.095 | Acc: 98.263%
# Test Loss: 0.009 | Acc: 97.833%
#
# Epoch: 156
# Train Loss: 0.096 | Acc: 98.235%
# Test Loss: 0.009 | Acc: 97.917%
#
# Epoch: 157
# Train Loss: 0.093 | Acc: 98.370%
# Test Loss: 0.010 | Acc: 97.667%
#
# Epoch: 158
# Train Loss: 0.092 | Acc: 98.348%
# Test Loss: 0.009 | Acc: 97.917%
#
# Epoch: 159
# Train Loss: 0.094 | Acc: 98.319%
# Test Loss: 0.010 | Acc: 97.708%
#
# Epoch: 160
# Train Loss: 0.094 | Acc: 98.329%
# Test Loss: 0.012 | Acc: 97.333%
#
# Epoch: 161
# Train Loss: 0.094 | Acc: 98.301%
# Test Loss: 0.010 | Acc: 97.583%
#
# Epoch: 162
# Train Loss: 0.094 | Acc: 98.301%
# Test Loss: 0.010 | Acc: 97.917%
#
# Epoch: 163
# Train Loss: 0.096 | Acc: 98.279%
# Test Loss: 0.010 | Acc: 97.750%
#
# Epoch: 164
# Train Loss: 0.093 | Acc: 98.354%
# Test Loss: 0.009 | Acc: 98.000%
#
# Epoch: 165
# Train Loss: 0.092 | Acc: 98.335%
# Test Loss: 0.011 | Acc: 97.750%
#
# Epoch: 166
# Train Loss: 0.092 | Acc: 98.332%
# Test Loss: 0.009 | Acc: 97.958%
#
# Epoch: 167
# Train Loss: 0.090 | Acc: 98.360%
# Test Loss: 0.010 | Acc: 97.833%
#
# Epoch: 168
# Train Loss: 0.093 | Acc: 98.342%
# Test Loss: 0.010 | Acc: 97.667%
#
# Epoch: 169
# Train Loss: 0.090 | Acc: 98.345%
# Test Loss: 0.010 | Acc: 97.792%
#
# Epoch: 170
# Train Loss: 0.093 | Acc: 98.297%
# Test Loss: 0.010 | Acc: 97.875%
#
# Epoch: 171
# Train Loss: 0.095 | Acc: 98.250%
# Test Loss: 0.009 | Acc: 98.000%
#
# Epoch: 172
# Train Loss: 0.097 | Acc: 98.209%
# Test Loss: 0.010 | Acc: 97.750%
#
# Epoch: 173
# Train Loss: 0.089 | Acc: 98.411%
# Test Loss: 0.011 | Acc: 97.833%
#
# Epoch: 174
# Train Loss: 0.092 | Acc: 98.326%
# Test Loss: 0.010 | Acc: 97.833%
#
# Epoch: 175
# Train Loss: 0.090 | Acc: 98.351%
# Test Loss: 0.013 | Acc: 97.542%
#
# Epoch: 176
# Train Loss: 0.089 | Acc: 98.417%
# Test Loss: 0.009 | Acc: 97.917%
#
# Epoch: 177
# Train Loss: 0.089 | Acc: 98.398%
# Test Loss: 0.011 | Acc: 97.583%
#
# Epoch: 178
# Train Loss: 0.092 | Acc: 98.263%
# Test Loss: 0.012 | Acc: 97.542%
#
# Epoch: 179
# Train Loss: 0.092 | Acc: 98.354%
# Test Loss: 0.009 | Acc: 98.000%
#
# Epoch: 180
# Train Loss: 0.088 | Acc: 98.430%
# Test Loss: 0.011 | Acc: 97.667%
#
# Epoch: 181
# Train Loss: 0.090 | Acc: 98.316%
# Test Loss: 0.012 | Acc: 97.458%
#
# Epoch: 182
# Train Loss: 0.093 | Acc: 98.370%
# Test Loss: 0.009 | Acc: 98.083%
#
# Epoch: 183
# Train Loss: 0.086 | Acc: 98.436%
# Test Loss: 0.009 | Acc: 98.042%
#
# Epoch: 184
# Train Loss: 0.089 | Acc: 98.364%
# Test Loss: 0.013 | Acc: 97.458%
#
# Epoch: 185
# Train Loss: 0.088 | Acc: 98.392%
# Test Loss: 0.009 | Acc: 97.792%
#
# Epoch: 186
# Train Loss: 0.088 | Acc: 98.414%
# Test Loss: 0.010 | Acc: 97.542%
#
# Epoch: 187
# Train Loss: 0.089 | Acc: 98.395%
# Test Loss: 0.009 | Acc: 98.042%
#
# Epoch: 188
# Train Loss: 0.086 | Acc: 98.474%
# Test Loss: 0.010 | Acc: 97.833%
#
# Epoch: 189
# Train Loss: 0.086 | Acc: 98.458%
# Test Loss: 0.009 | Acc: 98.125%
#
# Epoch: 190
# Train Loss: 0.090 | Acc: 98.389%
# Test Loss: 0.011 | Acc: 97.792%
#
# Epoch: 191
# Train Loss: 0.086 | Acc: 98.445%
# Test Loss: 0.009 | Acc: 97.708%
#
# Epoch: 192
# Train Loss: 0.088 | Acc: 98.433%
# Test Loss: 0.010 | Acc: 97.917%
#
# Epoch: 193
# Train Loss: 0.092 | Acc: 98.247%
# Test Loss: 0.009 | Acc: 97.958%
#
# Epoch: 194
# Train Loss: 0.087 | Acc: 98.430%
# Test Loss: 0.011 | Acc: 97.500%
#
# Epoch: 195
# Train Loss: 0.090 | Acc: 98.367%
# Test Loss: 0.009 | Acc: 97.750%
#
# Epoch: 196
# Train Loss: 0.085 | Acc: 98.464%
# Test Loss: 0.009 | Acc: 97.875%
#
# Epoch: 197
# Train Loss: 0.087 | Acc: 98.458%
# Test Loss: 0.010 | Acc: 97.708%
#
# Epoch: 198
# Train Loss: 0.083 | Acc: 98.493%
# Test Loss: 0.012 | Acc: 97.042%
#
# Epoch: 199
# Train Loss: 0.086 | Acc: 98.426%
# Test Loss: 0.009 | Acc: 97.833%
#
# Epoch: 200
# Train Loss: 0.086 | Acc: 98.379%
# Test Loss: 0.009 | Acc: 97.875%
